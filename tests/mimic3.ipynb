# %%
! py -m pip install mycroft-mimic3-tts[all]

# %%
! mimic3 'Hello world.' | aplay

# %%
! py -m pip install TTS
# Out:
# ...
#                                               0.0/1.5 MB ? eta -:--:--
#      ---                                      0.1/1.5 MB 2.8 MB/s eta 0:00:01
#      ---------------                          0.6/1.5 MB 6.0 MB/s eta 0:00:01
#      --------------------------------         1.2/1.5 MB 8.6 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 8.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [273 lines of output]
# ...
#         Using cached setuptools-68.0.0-py3-none-any.whl (804 kB)
# ...
#         Using cached wheel-0.40.0-py3-none-any.whl (64 kB)
# ...
#                                                     0.0/985.1 kB ? eta -:--:--
#            ----                                   112.6/985.1 kB 3.2 MB/s eta 0:00:01
# ...
